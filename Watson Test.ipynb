# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio
# This is to test the IBM watson studio

# %% [markdown]
# __Eugen FA__

# %% [markdown]
# _I am interested in data science because of the all possibilities you can have to gather, store and manipulate data, the usage of these for machine learning models and for the benefits of AI in almost all industries._

# %% [markdown]
# ### Let's try addionning two numbers

# %%
# Lets try some arithmetics
a = 2
b = 5
print (a + b)
# Out:
# 7

# %% [markdown]
# Let's list what can we do in Watson studio
# 1. Data Analysis
# 2. Data Engineers
# 3. Construct models
# Here are some languages you can use in Watson
# * Python
# * R
# * Scala
# You can also use:
# ---------------
# | jubyterlab |
#
# | Github |
#
# Use this <a href = "https://dataplatform.cloud.ibm.com/docs/content/wsj/getting-started/df_tutorials.html?context=cpdaas&audience=wd"> to create an account</a>.

# %%
# Lets try some
n1 = 8
n2 = 5
n1 + n2
# Out:
# 13
